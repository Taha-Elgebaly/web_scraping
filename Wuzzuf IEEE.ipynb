# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = requests.get('https://wuzzuf.net/search/jobs/?a=spbg&q=data%20science')

# %%
url
# Out:
# <Response [200]>

# %%
content = url.content

# %%
soup = BeautifulSoup(content , 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <title data-react-helmet="true">Job Search | WUZZUF</title>
# ...

# %%
Job skills

# %%
jobs = soup.find_all('div',class_ = 'css-1gatmva e1v1l3u10')
len(jobs)
# Out:
# 15

# %%
Job_title = jobs[0].find_all('h2',class_ = "css-m604qf")[0].text

# %%
Job_title
# Out:
# 'Data Science Instructor'

# %%
Job_skills  =" // ".join(jobs[0].find_all('div',class_="css-1lh32fc")[0].next_sibling.text.split(' · ')[:])
Job_skills
# Out:
# 'Experienced // 1+ Yrs of Exp // IT/Software Development // Engineering - Telecom/Technology // Training/Instructor // Data Science // Computer Science // Computer Engineering // Python // Machine Learning // Deep Learning // Artificial Intelligence (AI)'

# %%
Job_type = soup.find_all('span',class_ = "css-1ve4b75 eoyjyou0")[0].text
Job_type
# Out:
# 'Full Time'

# %%
company_name = soup.find_all('div',class_ = "css-d7j1kk")[0].text.split(' - ')[0]
company_name
# Out:
# 'EpsilonAI'

# %%
location = soup.find_all('span',class_ = "css-5wys0k")[0].text
location
# Out:
# 'Nasr City, Cairo, Egypt '

# %%
Post_time = soup.find_all('div',class_ = "css-do6t5g")[2].text
Post_time
# Out:
# '14 days ago'

# %%
# first problem

# %%
ls = input()

ls_reverse = ls[::-1]

while ls_reverse and ls_reverse[0] == '0':
    ls_reverse = ls_reverse[1:]

if ls == ls_reverse:
    result = 'YES'
else:
    result = 'NO'

print(ls_reverse)
print(result)
# Out:
# 610
# 16
# NO

# %%
https://codeforces.com/group/MWSDmqGsZm/contest/219432/submission/226097781

# %%
#second problem 

https://codeforces.com/group/MWSDmqGsZm/contest/219432/submission/226098239
